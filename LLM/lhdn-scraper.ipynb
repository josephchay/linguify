# %%
## Individual TAX information

import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse, urlunparse
import time
from random import uniform

HEADERS = {
    "User-Agent": "Mozilla/5.0"
}

visited = set()

def extract_table_as_markdown(table):
    """Improved table converter with better handling of complex table structures"""
    rows = []
    max_cols = 0
    
    # Process all rows to find the maximum number of columns
    for tr in table.find_all('tr'):
        cells = tr.find_all(['th', 'td'])
        max_cols = max(max_cols, len(cells))
        row_data = []
        for cell in cells:
            # Clean text and handle non-breaking spaces
            text = cell.get_text(strip=True).replace('\xa0', ' ')
            row_data.append(text)
        if row_data:  # Skip empty rows
            rows.append(row_data)
    
    if not rows:
        return ""
    
    # Ensure all rows have the same number of columns
    for i, row in enumerate(rows):
        if len(row) < max_cols:
            rows[i].extend([''] * (max_cols - len(row)))
    
    # Create markdown table
    markdown = []
    markdown.append('| ' + ' | '.join(rows[0]) + ' |')
    markdown.append('|' + '|'.join(['-' * (len(col) + 2) for col in rows[0]]) + '|')
    
    for row in rows[1:]:
        markdown.append('| ' + ' | '.join(row) + ' |')
    
    return '\n'.join(markdown)

def get_page_text_and_links(url):
    try:
        time.sleep(uniform(1, 3))  # Be nice to the server
        response = requests.get(url, headers=HEADERS, timeout=15)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, "html.parser")
        content_divs = soup.select("div[class*='content-col']")

        links = set()
        content = []
        seen_content = set()

        for div in content_divs:
            # Remove junk tags
            for tag in div(['script', 'style', 'nav', 'footer', 'iframe']):
                tag.decompose()

            # Process content in its original order
            for element in div.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'ul', 'ol', 'table']):
                if element.name == 'table':
                    # Convert table to markdown
                    markdown_table = extract_table_as_markdown(element)
                    if markdown_table:
                        content.append(markdown_table)

                    element.decompose()
                else:
                    # Process regular text elements
                    text = element.get_text('\n', strip=True)
                    if text and text not in seen_content:
                        content.append(text)
                        seen_content.add(text)
                        
        for a in soup.find_all("a", href=True):
            href = a['href']
            full_url = urljoin(url, href)
            parsed = urlparse(full_url)

            # Strip the fragment (e.g. #site-content)
            cleaned_url = urlunparse(parsed._replace(fragment=""))

            if parsed.netloc == "www.hasil.gov.my" and parsed.path.startswith("/en/individual"):
                links.add(cleaned_url)

        final_content = "\n".join(content)
        return final_content, sorted(links)

    except Exception as e:
        print(f"❌ Error scraping {url}: {e}")
        return None, set()

def scrape_all_individual_pages(start_url):
    to_visit = [start_url]
    scraped_data = {}

    while to_visit:
        current_url = to_visit.pop(0)
        if current_url in visited:
            continue

        visited.add(current_url)
        print(f"Scraping: {current_url}")

        page_text, found_links = get_page_text_and_links(current_url)
        if page_text:
            scraped_data[current_url] = page_text

        for link in found_links:
            if link not in visited and link not in to_visit:
                to_visit.append(link)
    print(f"✅ Total links visited: {len(visited)}")
        
    return scraped_data

# Start from main individual page
root_url = "https://www.hasil.gov.my/en/individual/"
results = scrape_all_individual_pages(root_url)

# Save results
with open("lhdn-test.txt", "w", encoding="utf-8") as f:
    for url, content in results.items():
        f.write(f"\n--- {url} ---\n{content}\n")
# Out:
# Scraping: https://www.hasil.gov.my/en/individual/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/registration/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/residence-status/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/
# ❌ Error scraping https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/: HTTPSConnectionPool(host='www.hasil.gov.my', port=443): Read timed out. (read timeout=15)
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/how-to-file-your-tax/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/how-to-submit-your-itrf/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/what-is-income-tax/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/when-is-taxable/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/who-is-taxable/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/why-must-we-pay-tax/
# Scraping: https://www.hasil.gov.my/en/individual/others/
# Scraping: https://www.hasil.gov.my/en/individual/others/amended-assessment/
# Scraping: https://www.hasil.gov.my/en/individual/others/appeal/
# Scraping: https://www.hasil.gov.my/en/individual/others/frequently-asked-question-individual/
# Scraping: https://www.hasil.gov.my/en/individual/others/offences/
# Scraping: https://www.hasil.gov.my/en/individual/others/review-update/
# Scraping: https://www.hasil.gov.my/en/individual/others/stoppage-order/
# Scraping: https://www.hasil.gov.my/en/individual/others/termination-of-service-employment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/business-code/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/donations-gifts/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/itrf-deadlines/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/manual/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/online/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/rebates/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/tax-rate/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/tax-reliefs/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/type-of-assessment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/balance-of-tax-payment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/mode-of-payment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/penalty-on-late-payment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/tax-estimation-advance-payment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/tax-refund/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/registration/automatic/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/registration/manual/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/registration/online-e-daftar/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/residence-status/certificate-of-residence/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/residence-status/section-7/
# Scraping: https://www.hasil.gov.my/en/individual/others/amended-assessment/arf/
# Scraping: https://www.hasil.gov.my/en/individual/others/amended-assessment/e-filing-e-application-for-amended-be/
# Scraping: https://www.hasil.gov.my/en/individual/others/amended-assessment/manual/
# ✅ Total links visited: 43

# %%
## Company TAX information

import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse, urlunparse
import time
from random import uniform

HEADERS = {
    "User-Agent": "Mozilla/5.0"
}

visited = set()

def extract_table_as_markdown(table):
    """Improved table converter with better handling of complex table structures"""
    rows = []
    max_cols = 0
    
    # Process all rows to find the maximum number of columns
    for tr in table.find_all('tr'):
        cells = tr.find_all(['th', 'td'])
        max_cols = max(max_cols, len(cells))
        row_data = []
        for cell in cells:
            # Clean text and handle non-breaking spaces
            text = cell.get_text(strip=True).replace('\xa0', ' ')
            row_data.append(text)
        if row_data:  # Skip empty rows
            rows.append(row_data)
    
    if not rows:
        return ""
    
    # Ensure all rows have the same number of columns
    for i, row in enumerate(rows):
        if len(row) < max_cols:
            rows[i].extend([''] * (max_cols - len(row)))
    
    # Create markdown table
    markdown = []
    markdown.append('| ' + ' | '.join(rows[0]) + ' |')
    markdown.append('|' + '|'.join(['-' * (len(col) + 2) for col in rows[0]]) + '|')
    
    for row in rows[1:]:
        markdown.append('| ' + ' | '.join(row) + ' |')
    
    return '\n'.join(markdown)

def get_page_text_and_links(url):
    try:
        time.sleep(uniform(1, 3))  # Be nice to the server
        response = requests.get(url, headers=HEADERS, timeout=15)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, "html.parser")
        content_divs = soup.select("div[class*='content-col']")

        links = set()
        content = []
        seen_content = set()

        for div in content_divs:
            # Remove junk tags
            for tag in div(['script', 'style', 'nav', 'footer', 'iframe']):
                tag.decompose()

            # Process content in its original order
            for element in div.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'ul', 'ol', 'table']):
                if element.name == 'table':
                    # Convert table to markdown
                    markdown_table = extract_table_as_markdown(element)
                    if markdown_table:
                        content.append(markdown_table)

                    element.decompose()
                else:
                    # Process regular text elements
                    text = element.get_text('\n', strip=True)
                    if text and text not in seen_content:
                        content.append(text)
                        seen_content.add(text)
                        
        for a in soup.find_all("a", href=True):
            href = a['href']
            full_url = urljoin(url, href)
            parsed = urlparse(full_url)

            # Strip the fragment (e.g. #site-content)
            cleaned_url = urlunparse(parsed._replace(fragment=""))

            if parsed.netloc == "www.hasil.gov.my" and parsed.path.startswith("/en/company"):
                links.add(cleaned_url)

        final_content = "\n".join(content)
        return final_content, sorted(links)

    except Exception as e:
        print(f"❌ Error scraping {url}: {e}")
        return None, set()

def scrape_all_individual_pages(start_url):
    to_visit = [start_url]
    scraped_data = {}

    while to_visit:
        current_url = to_visit.pop(0)
        if current_url in visited:
            continue

        visited.add(current_url)
        print(f"Scraping: {current_url}")

        page_text, found_links = get_page_text_and_links(current_url)
        if page_text:
            scraped_data[current_url] = page_text

        for link in found_links:
            if link not in visited and link not in to_visit:
                to_visit.append(link)
    print(f"✅ Total links visited: {len(visited)}")
        
    return scraped_data

# Start from main individual page
root_url = "https://www.hasil.gov.my/en/company/"
results = scrape_all_individual_pages(root_url)

# Save results
with open("lhdn-company.txt", "w", encoding="utf-8") as f:
    for url, content in results.items():
        f.write(f"\n--- {url} ---\n{content}\n")
# Out:
# Scraping: https://www.hasil.gov.my/en/company/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/appeal/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/appeal/application-for-relief-under-the-ita/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/', 'https://www.hasil.gov.my/en/company/appeal/dispute-resolution-proceedings-drp/'}
# Scraping: https://www.hasil.gov.my/en/company/basis-period-for-company/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/certificate-of-resident/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/change-in-accounting-period/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/company-resident-status/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/cooporative-tax/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/corporate-tax/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/digital-business/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/digital-business/e-daftar/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/frequently-asked-question-company/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/non-resident-company/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/other-situation/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/sme/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/tax-estimation/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/tax-file-registration/
# ❌ Error scraping https://www.hasil.gov.my/en/company/tax-file-registration/: HTTPSConnectionPool(host='www.hasil.gov.my', port=443): Read timed out. (read timeout=15)
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/tax-payment/application-to-pay-balance-of-tax-by-installments/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/tax-payment/payment-method/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment-code-at-commercial-banks-and-post-office/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/', 'https://www.hasil.gov.my/en/company/tax-payment/enquiry-of-tax-position/'}
# Scraping: https://www.hasil.gov.my/en/company/tax-rate-of-company/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/taxpayer-responsibilities/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/update-company-information/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/appeal/application-for-relief-under-the-ita/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/appeal/application-for-relief-under-the-ita/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/', 'https://www.hasil.gov.my/en/company/appeal/dispute-resolution-proceedings-drp/'}
# Scraping: https://www.hasil.gov.my/en/company/appeal/dispute-resolution-proceedings-drp/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/appeal/application-for-relief-under-the-ita/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/appeal/dispute-resolution-proceedings-drp/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/digital-business/e-daftar/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/digital-business/e-daftar/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/'}
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/application-to-pay-balance-of-tax-by-installments/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/tax-payment/application-to-pay-balance-of-tax-by-installments/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/tax-payment/payment-method/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment-code-at-commercial-banks-and-post-office/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/', 'https://www.hasil.gov.my/en/company/tax-payment/enquiry-of-tax-position/'}
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/enquiry-of-tax-position/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/tax-payment/application-to-pay-balance-of-tax-by-installments/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/tax-payment/payment-method/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment-code-at-commercial-banks-and-post-office/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/', 'https://www.hasil.gov.my/en/company/tax-payment/enquiry-of-tax-position/'}
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/payment-method/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/tax-payment/application-to-pay-balance-of-tax-by-installments/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/tax-payment/payment-method/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment-code-at-commercial-banks-and-post-office/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/', 'https://www.hasil.gov.my/en/company/tax-payment/enquiry-of-tax-position/'}
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/tax-payment-code-at-commercial-banks-and-post-office/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/tax-payment/application-to-pay-balance-of-tax-by-installments/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/tax-payment/payment-method/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment-code-at-commercial-banks-and-post-office/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/', 'https://www.hasil.gov.my/en/company/tax-payment/enquiry-of-tax-position/'}
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/tax-payment/
# {'https://www.hasil.gov.my/en/company/corporate-tax/', 'https://www.hasil.gov.my/en/company/tax-payment/application-to-pay-balance-of-tax-by-installments/', 'https://www.hasil.gov.my/en/company/digital-business/', 'https://www.hasil.gov.my/en/company/appeal/', 'https://www.hasil.gov.my/en/company/', 'https://www.hasil.gov.my/en/company/cooporative-tax/', 'https://www.hasil.gov.my/en/company/frequently-asked-question-company/', 'https://www.hasil.gov.my/en/company/tax-rate-of-company/', 'https://www.hasil.gov.my/en/company/basis-period-for-company/', 'https://www.hasil.gov.my/en/company/company-resident-status/', 'https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/', 'https://www.hasil.gov.my/en/company/certificate-of-resident/', 'https://www.hasil.gov.my/en/company/tax-estimation/', 'https://www.hasil.gov.my/en/company/tax-payment/payment-method/', 'https://www.hasil.gov.my/en/company/update-company-information/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment-code-at-commercial-banks-and-post-office/', 'https://www.hasil.gov.my/en/company/non-resident-company/', 'https://www.hasil.gov.my/en/company/other-situation/', 'https://www.hasil.gov.my/en/company/tax-payment/tax-payment/', 'https://www.hasil.gov.my/en/company/sme/', 'https://www.hasil.gov.my/en/company/change-in-accounting-period/', 'https://www.hasil.gov.my/en/company/taxpayer-responsibilities/', 'https://www.hasil.gov.my/en/company/tax-payment/', 'https://www.hasil.gov.my/en/company/tax-file-registration/', 'https://www.hasil.gov.my/en/company/tax-payment/enquiry-of-tax-position/'}

# %%
## TEST information

import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse, urlunparse
import time
from random import uniform

HEADERS = {
    "User-Agent": "Mozilla/5.0"
}

visited = set()

def extract_table_as_markdown(table):
    """Improved table converter with better handling of complex table structures"""
    rows = []
    max_cols = 0
    
    # Process all rows to find the maximum number of columns
    for tr in table.find_all('tr'):
        cells = tr.find_all(['th', 'td'])
        max_cols = max(max_cols, len(cells))
        row_data = []
        for cell in cells:
            # Clean text and handle non-breaking spaces
            text = cell.get_text(strip=True).replace('\xa0', ' ')
            row_data.append(text)
        if row_data:  # Skip empty rows
            rows.append(row_data)
    
    if not rows:
        return ""
    
    # Ensure all rows have the same number of columns
    for i, row in enumerate(rows):
        if len(row) < max_cols:
            rows[i].extend([''] * (max_cols - len(row)))
    
    # Create markdown table
    markdown = []
    markdown.append('| ' + ' | '.join(rows[0]) + ' |')
    markdown.append('|' + '|'.join(['-' * (len(col) + 2) for col in rows[0]]) + '|')
    
    for row in rows[1:]:
        markdown.append('| ' + ' | '.join(row) + ' |')
    
    return '\n'.join(markdown)

def get_page_text_and_links(url):
    try:
        time.sleep(uniform(1, 3))  # Be nice to the server
        response = requests.get(url, headers=HEADERS, timeout=15)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, "html.parser")
        content_divs = soup.select("div[class*='content-col']")

        links = set()
        content = []
        seen_content = set()

        for div in content_divs:
            # Remove junk tags
            for tag in div(['script', 'style', 'nav', 'footer', 'iframe']):
                tag.decompose()

            # Process content in its original order
            for element in div.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'ul', 'ol', 'table']):
                if element.name == 'table':
                    # Convert table to markdown
                    markdown_table = extract_table_as_markdown(element)
                    if markdown_table:
                        content.append(markdown_table)

                    element.decompose()
                else:
                    # Process regular text elements
                    text = element.get_text('\n', strip=True)
                    if text and text not in seen_content:
                        content.append(text)
                        seen_content.add(text)
                        
        for a in soup.find_all("a", href=True):
            href = a['href']
            full_url = urljoin(url, href)
            parsed = urlparse(full_url)

            # Strip the fragment (e.g. #site-content)
            cleaned_url = urlunparse(parsed._replace(fragment=""))

            if parsed.netloc == "www.hasil.gov.my" and parsed.path.startswith("/en"):
                links.add(cleaned_url)

        final_content = "\n".join(content)
        return final_content, sorted(links)

    except Exception as e:
        print(f"❌ Error scraping {url}: {e}")
        return None, set()

def scrape_all_individual_pages(start_url):
    to_visit = [start_url]
    scraped_data = {}

    while to_visit:
        current_url = to_visit.pop(0)
        if current_url in visited:
            continue

        visited.add(current_url)
        print(f"Scraping: {current_url}")

        page_text, found_links = get_page_text_and_links(current_url)
        if page_text:
            scraped_data[current_url] = page_text

        for link in found_links:
            if link not in visited and link not in to_visit:
                to_visit.append(link)
    print(f"✅ Total links visited: {len(visited)}")
        
    return scraped_data

# Start from main individual page
root_url = "https://www.hasil.gov.my/en/"
results = scrape_all_individual_pages(root_url)

# Save results
with open("lhdn-test.txt", "w", encoding="utf-8") as f:
    for url, content in results.items():
        f.write(f"\n--- {url} ---\n{content}\n")
# Out:
# Scraping: https://www.hasil.gov.my/en/
# Scraping: https://www.hasil.gov.my/en/about-hasil/
# Scraping: https://www.hasil.gov.my/en/about-hasil/academy/
# Scraping: https://www.hasil.gov.my/en/about-hasil/best-tax-payer-award/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-culture/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/
# Scraping: https://www.hasil.gov.my/en/about-hasil/hasil-directory/
# Scraping: https://www.hasil.gov.my/en/about-hasil/hasil-integrity/
# Scraping: https://www.hasil.gov.my/en/announcement/?tajuk=
# Scraping: https://www.hasil.gov.my/en/beware-of-tax-scams/
# Scraping: https://www.hasil.gov.my/en/career/
# Scraping: https://www.hasil.gov.my/en/company/
# Scraping: https://www.hasil.gov.my/en/company/amending-the-income-tax-return-form/
# Scraping: https://www.hasil.gov.my/en/company/appeal/
# Scraping: https://www.hasil.gov.my/en/company/basis-period-for-company/
# Scraping: https://www.hasil.gov.my/en/company/certificate-of-resident/
# Scraping: https://www.hasil.gov.my/en/company/change-in-accounting-period/
# Scraping: https://www.hasil.gov.my/en/company/company-resident-status/
# Scraping: https://www.hasil.gov.my/en/company/cooporative-tax/
# Scraping: https://www.hasil.gov.my/en/company/corporate-tax/
# Scraping: https://www.hasil.gov.my/en/company/digital-business/
# Scraping: https://www.hasil.gov.my/en/company/frequently-asked-question-company/
# Scraping: https://www.hasil.gov.my/en/company/non-resident-company/
# Scraping: https://www.hasil.gov.my/en/company/other-situation/
# Scraping: https://www.hasil.gov.my/en/company/sme/
# Scraping: https://www.hasil.gov.my/en/company/tax-estimation/
# Scraping: https://www.hasil.gov.my/en/company/tax-file-registration/
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/
# Scraping: https://www.hasil.gov.my/en/company/tax-rate-of-company/
# Scraping: https://www.hasil.gov.my/en/company/taxpayer-responsibilities/
# Scraping: https://www.hasil.gov.my/en/company/update-company-information/
# Scraping: https://www.hasil.gov.my/en/contact-us/
# Scraping: https://www.hasil.gov.my/en/contact-us/report-tax-evasion/
# Scraping: https://www.hasil.gov.my/en/e-Services/
# Scraping: https://www.hasil.gov.my/en/e-invoice/
# Scraping: https://www.hasil.gov.my/en/e-invoice/reference-for-the-implementation-of-e-invoice/guidelines/
# Scraping: https://www.hasil.gov.my/en/e-services/
# Scraping: https://www.hasil.gov.my/en/eduzone/
# Scraping: https://www.hasil.gov.my/en/eduzone/interview-video/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-benefits-video/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-calculation-and-calculator/tax-calculator/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-education-awareness-video/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-slide-poster/
# Scraping: https://www.hasil.gov.my/en/employers/
# Scraping: https://www.hasil.gov.my/en/employers/employer-payroll-data-specification/
# Scraping: https://www.hasil.gov.my/en/employers/frequently-asked-question/
# Scraping: https://www.hasil.gov.my/en/employers/guideline/
# Scraping: https://www.hasil.gov.my/en/employers/list-of-software-provider-or-employer/
# Scraping: https://www.hasil.gov.my/en/employers/method/
# Scraping: https://www.hasil.gov.my/en/employers/mtd-payment/
# Scraping: https://www.hasil.gov.my/en/employers/mtd-schedular/
# Scraping: https://www.hasil.gov.my/en/employers/notifications-of-new-employee/
# Scraping: https://www.hasil.gov.my/en/employers/notifications-of-termination-of-service/
# Scraping: https://www.hasil.gov.my/en/employers/responsibility-of-employer/
# Scraping: https://www.hasil.gov.my/en/forms/
# Scraping: https://www.hasil.gov.my/en/forms/cgt-return-form-filing-programme/
# Scraping: https://www.hasil.gov.my/en/forms/criteria-on-incomplete-itrf/
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/
# Scraping: https://www.hasil.gov.my/en/forms/filing-programme-for-documents-specified-under-section-82b-through-mitrs/
# Scraping: https://www.hasil.gov.my/en/forms/return-form-rf-filing-programme/
# Scraping: https://www.hasil.gov.my/en/forms/rpgt-return-form-filing-programme/
# Scraping: https://www.hasil.gov.my/en/individual/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/registration/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/residence-status/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/how-to-file-your-tax/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/how-to-submit-your-itrf/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/what-is-income-tax/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/when-is-taxable/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/who-is-taxable/
# Scraping: https://www.hasil.gov.my/en/individual/introduction-individual-income-tax/why-must-we-pay-tax/
# Scraping: https://www.hasil.gov.my/en/individual/others/
# Scraping: https://www.hasil.gov.my/en/individual/others/amended-assessment/
# Scraping: https://www.hasil.gov.my/en/individual/others/appeal/
# Scraping: https://www.hasil.gov.my/en/individual/others/frequently-asked-question-individual/
# Scraping: https://www.hasil.gov.my/en/individual/others/offences/
# Scraping: https://www.hasil.gov.my/en/individual/others/review-update/
# Scraping: https://www.hasil.gov.my/en/individual/others/stoppage-order/
# Scraping: https://www.hasil.gov.my/en/individual/others/termination-of-service-employment/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/application-info/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/donation-receipts/
# ❌ Error scraping https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/donation-receipts/: HTTPSConnectionPool(host='www.hasil.gov.my', port=443): Read timed out. (read timeout=15)
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/frequently-asked-questions/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/public-info/
# Scraping: https://www.hasil.gov.my/en/international/
# Scraping: https://www.hasil.gov.my/en/international/advance-pricing-arrangement-apa/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/
# Scraping: https://www.hasil.gov.my/en/international/average-lending-rate-bank-negara-malaysia-schedule-section-140b/
# Scraping: https://www.hasil.gov.my/en/international/certificate-of-residence-e-residence/
# Scraping: https://www.hasil.gov.my/en/international/double-taxation-avoidance-agreement-dta/
# Scraping: https://www.hasil.gov.my/en/international/exchange-of-information/
# Scraping: https://www.hasil.gov.my/en/international/foreign-exchange-rate/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/
# Scraping: https://www.hasil.gov.my/en/international/incentives/
# Scraping: https://www.hasil.gov.my/en/international/international-affairs/
# Scraping: https://www.hasil.gov.my/en/international/irbm-public-key/
# Scraping: https://www.hasil.gov.my/en/international/multilateral-instrument-mli/
# Scraping: https://www.hasil.gov.my/en/international/mutual-agreement-procedure-map/
# Scraping: https://www.hasil.gov.my/en/international/non-resident/
# Scraping: https://www.hasil.gov.my/en/international/restriction-on-deductibility-of-interest-section-140c-income-tax-act-1967/
# Scraping: https://www.hasil.gov.my/en/international/transfer-pricing/
# ❌ Error scraping https://www.hasil.gov.my/en/international/transfer-pricing/: HTTPSConnectionPool(host='www.hasil.gov.my', port=443): Read timed out. (read timeout=15)
# Scraping: https://www.hasil.gov.my/en/legislation/
# Scraping: https://www.hasil.gov.my/en/legislation/act/
# Scraping: https://www.hasil.gov.my/en/legislation/budget/
# Scraping: https://www.hasil.gov.my/en/legislation/dialog-minutes-for-operational-technical-issues/
# Scraping: https://www.hasil.gov.my/en/legislation/framework/
# Scraping: https://www.hasil.gov.my/en/legislation/guidelines/
# Scraping: https://www.hasil.gov.my/en/legislation/offences-fines-and-penalties/
# Scraping: https://www.hasil.gov.my/en/legislation/practice-note/
# Scraping: https://www.hasil.gov.my/en/legislation/public-rulings/
# Scraping: https://www.hasil.gov.my/en/legislation/tax-case/
# Scraping: https://www.hasil.gov.my/en/legislation/withholding-tax/
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=1bdff000-7621-402a-89c9-a331ac665497
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=ee7dadb1-7909-4c34-a7cd-5c1b09602f8c
# Scraping: https://www.hasil.gov.my/en/media-release/
# Scraping: https://www.hasil.gov.my/en/my-situation/
# Scraping: https://www.hasil.gov.my/en/my-situation/frequently-asked-questions-faq/
# Scraping: https://www.hasil.gov.my/en/online-security/?bt_kump=20&bt_skum=1&bt_posi=1&bt_unit=4&bt_sequ=1
# Scraping: https://www.hasil.gov.my/en/privacy-policy/?bt_kump=20&bt_skum=1&bt_posi=1&bt_unit=2&bt_sequ=1
# Scraping: https://www.hasil.gov.my/en/quick-links/
# Scraping: https://www.hasil.gov.my/en/quick-links/governments-special-aid/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/donation-approval/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/engagement-session/
# Scraping: https://www.hasil.gov.my/en/rpgt/
# Scraping: https://www.hasil.gov.my/en/rpgt/assessment-of-real-property-gain-tax/
# Scraping: https://www.hasil.gov.my/en/rpgt/determination-of-chargeable-gain-allowable-loss/
# Scraping: https://www.hasil.gov.my/en/rpgt/disposal-date-and-acquisition-date/
# Scraping: https://www.hasil.gov.my/en/rpgt/disposal-price-and-acquisition-price/
# Scraping: https://www.hasil.gov.my/en/rpgt/disposal-price-deemed-to-be-equal-to-acquisition-price/
# Scraping: https://www.hasil.gov.my/en/rpgt/exemption/
# Scraping: https://www.hasil.gov.my/en/rpgt/imposition-of-penalties-and-increases-of-tax/
# Scraping: https://www.hasil.gov.my/en/rpgt/jenis-borang-nyata-ckht/
# Scraping: https://www.hasil.gov.my/en/rpgt/pegangan-dan-remitan-wang-oleh-pemeroleh-available-in-malay-language-only/
# Scraping: https://www.hasil.gov.my/en/rpgt/pengenalan-sistem-taksir-sendiri-ckht-sts-ckht/
# Scraping: https://www.hasil.gov.my/en/rpgt/pindaan-borang-nyata-ckht/
# Scraping: https://www.hasil.gov.my/en/rpgt/procedures-for-submission-of-real-property-gains-tax-form/
# Scraping: https://www.hasil.gov.my/en/rpgt/prosedur-bayaran-ckht/
# Scraping: https://www.hasil.gov.my/en/rpgt/real-property-gains-tax-rpgt-rates/
# Scraping: https://www.hasil.gov.my/en/rpgt/responsibility-of-disposer-and-acquirer/
# Scraping: https://www.hasil.gov.my/en/rpgt/shares-in-real-property-company-rpc/
# Scraping: https://www.hasil.gov.my/en/rpgt/transfer-of-asset-inherited-from-deceased-estate/
# Scraping: https://www.hasil.gov.my/en/security-policy/?bt_kump=20&bt_skum=1&bt_posi=1&bt_unit=3&bt_sequ=1
# Scraping: https://www.hasil.gov.my/en/sitemap/
# Scraping: https://www.hasil.gov.my/en/special-voluntary-disclosure-programme-svdp-20/
# Scraping: https://www.hasil.gov.my/en/stamp-duty/
# Scraping: https://www.hasil.gov.my/en/stamp-duty/amendments-to-the-stamps-act-1949/
# Scraping: https://www.hasil.gov.my/en/stamp-duty/method-of-payment/
# Scraping: https://www.hasil.gov.my/en/stamp-duty/penalty-stamp-duty/
# Scraping: https://www.hasil.gov.my/en/stamp-duty/primary-customer-responsibilities-lawyer-company-secretary-registrar-banking-and-financial-institutions-stamps-system/
# Scraping: https://www.hasil.gov.my/en/stamp-duty/relief-from-stamp-duty/
# Scraping: https://www.hasil.gov.my/en/stamp-duty/responsibility-of-solicitors/
# Scraping: https://www.hasil.gov.my/en/stamp-duty/stamp-duty-exemption-order-explanation/
# Scraping: https://www.hasil.gov.my/en/stamp-duty/stamp-duty-order/
# Scraping: https://www.hasil.gov.my/en/tax-agent/
# Scraping: https://www.hasil.gov.my/en/tax-agent/appointment-of-tax-agent-by-taxpayer/
# Scraping: https://www.hasil.gov.my/en/tax-agent/consultation-with-hasil/
# Scraping: https://www.hasil.gov.my/en/tax-agent/non-compliance-and-offences/
# Scraping: https://www.hasil.gov.my/en/tax-agent/profession-as-a-tax-agent/
# Scraping: https://www.hasil.gov.my/en/top-pages/
# Scraping: https://www.hasil.gov.my/en/about-hasil/best-tax-payer-award/recipient-year-2023/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/annual-report/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/client-charter/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/irbm-corporate-plan/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/irbm-profile/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/members-of-the-board/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/message-from-ceo/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/message-from-the-chief-digital-officer/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/organization-chart/
# Scraping: https://www.hasil.gov.my/en/about-hasil/hasil-directory/chief-executive-officer-office/
# Scraping: https://www.hasil.gov.my/en/about-hasil/hasil-directory/sector-department-academy/
# Scraping: https://www.hasil.gov.my/en/about-hasil/hasil-directory/state-irbm/
# Scraping: http://www.hasil.gov.my/en/announcement/?tajuk=&page=1
# ❌ Error scraping http://www.hasil.gov.my/en/announcement/?tajuk=&page=1: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/announcement/?tajuk=&page=2
# ❌ Error scraping http://www.hasil.gov.my/en/announcement/?tajuk=&page=2: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/announcement/?tajuk=&page=3
# ❌ Error scraping http://www.hasil.gov.my/en/announcement/?tajuk=&page=3: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/announcement/?tajuk=&page=4
# ❌ Error scraping http://www.hasil.gov.my/en/announcement/?tajuk=&page=4: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=003eec70-23a6-41b4-84ca-ac5d6251fab5
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=0e496bca-f9ce-4fa8-8418-7b3b464f6604
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=12e526c7-978a-41b6-a397-9792ded7ecff
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=1d89b1f7-d89c-445f-a100-f58aff979408
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=1e01eaeb-4468-4e16-9a91-c4f8342e3e0b
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=2d37297b-d409-42fb-8200-b27d99559d4e
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=3029d183-df3f-44fe-9bef-55c16952bbc3
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=320cc8a6-306a-46f6-86f5-5e6a03be1fdc
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=52a4ec2b-f0c6-41df-835f-c4b837718f6c
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=696278ee-6d57-4b9c-acff-c265bf765de7
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=712561a0-b98f-4199-9d38-1d6e3011cfd6
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=777d132b-9905-472b-acaa-ecb85d34d5d1
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=79108e2a-2d79-4600-917c-c07f9bf5676e
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=9aec350a-f46f-4af3-a8f9-b15ff76b6a1c
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=9deb57bd-2667-4260-b5e8-396c34589dc5
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=ae3d498b-f9d3-45d0-bbf7-4d37f829075e
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=b2db012a-cea7-4ca1-949d-73529f2268c5
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=b2f3eab5-2f2a-4daa-86af-d093dcf70218
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=bf6e5a7c-e53f-462c-a97b-b3c19c17011e
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=c9645eb0-b66e-459f-b405-0182c7dd9953
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=dc6226f4-e085-4921-b1ae-647d36212ff4
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=def0ea2b-ec30-4720-b207-fd1db6b1fdf5
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=ec5d491f-2d55-4837-b348-70c60269ca39
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=f1ced075-c3c6-44d6-96df-e9ff3608d4ec
# Scraping: https://www.hasil.gov.my/en/announcement-detail/?recordId=f68efb9d-c3f0-477a-9223-29b7eba9b63c
# Scraping: https://www.hasil.gov.my/en/company/appeal/application-for-relief-under-the-ita/
# Scraping: https://www.hasil.gov.my/en/company/appeal/dispute-resolution-proceedings-drp/
# Scraping: https://www.hasil.gov.my/en/company/digital-business/e-daftar/
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/application-to-pay-balance-of-tax-by-installments/
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/enquiry-of-tax-position/
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/payment-method/
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/tax-payment-code-at-commercial-banks-and-post-office/
# Scraping: https://www.hasil.gov.my/en/company/tax-payment/tax-payment/
# Scraping: https://www.hasil.gov.my/en/contact-us/call/call-centre/
# ❌ Error scraping https://www.hasil.gov.my/en/contact-us/call/call-centre/: 404 Client Error: Not Found for url: https://www.hasil.gov.my/en/contact-us/call/call-centre/
# Scraping: https://www.hasil.gov.my/en/contact-us/customer-care-officer/
# Scraping: https://www.hasil.gov.my/en/contact-us/report-misconduct-of-officer/
# Scraping: https://www.hasil.gov.my/en/contact-us/submit-to-us/
# Scraping: https://www.hasil.gov.my/en/contact-us/submit-to-us/hasil-helpdesk/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/
# Scraping: https://www.hasil.gov.my/en/e-invoice/communication-and-publicity/
# Scraping: https://www.hasil.gov.my/en/e-invoice/contact-us/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/
# Scraping: https://www.hasil.gov.my/en/e-invoice/implementation-of-e-invoicing-in-malaysia/
# Scraping: https://www.hasil.gov.my/en/e-invoice/myinvois-portal/
# Scraping: https://www.hasil.gov.my/en/e-invoice/reference-for-the-implementation-of-e-invoice/
# Scraping: https://www.hasil.gov.my/en/e-invoice/reference-for-the-implementation-of-e-invoice/e-invoice-software-development-kit-sdk/
# Scraping: https://www.hasil.gov.my/en/e-invoice/reference-for-the-implementation-of-e-invoice/frequently-asked-questions/
# Scraping: https://www.hasil.gov.my/en/e-invoice/reference-for-the-implementation-of-e-invoice/guidelines/e-invoice-illustration-guide/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-calculation-and-calculator/
# Scraping: https://www.hasil.gov.my/en/eduzone/taxedu-podcast/
# Scraping: https://www.hasil.gov.my/en/eduzone/tv-commercial/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/permohonan-lawatan-ke-pejabat-hasil/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/permohonan-penceramah-hasil/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/hasil/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/kelantan/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/negeri-sembilan/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/perak/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/pulau-pinang/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/sabah/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/selangor/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/terengganu/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2010/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2011/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2012/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2013/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2014/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2015/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2016/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2017/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2018/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2019/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2020/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2021/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2025/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-calculation-and-calculator/business-profit-and-loss-account-template/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/articles/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/comics/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/e-newsletter-hasil/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/hasilian-research-snapshot-hrs/
# Scraping: https://www.hasil.gov.my/en/forms/sample-of-dividend-voucher/
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-cgt/?subKategori=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-employer/?kategori=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-incentive-claim/?subKategoriTuntutan=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-individual/?subKategori=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-labuan-entity/?subKategori=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-non-company-non-individual/?subKategori=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-other-forms/?subKategoriLainLain=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-petroleum/?kategori=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-registration/?subKategoriPendaftaran=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-rpgt/?kategori=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-stamp-duty/?subKategori=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-withholding-tax/?subKategoriCukaiPegangan=Sila Pilih&tahun=0000
# ❌ Error scraping https://www.hasil.gov.my/en/forms/download-forms/download-form-withholding-tax/?subKategoriCukaiPegangan=Sila Pilih&tahun=0000: HTTPSConnectionPool(host='www.hasil.gov.my', port=443): Read timed out. (read timeout=15)
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-forms-company/?subKategori=Sila Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-rpgt/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/business-code/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/donations-gifts/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/itrf-deadlines/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/manual/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/online/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/rebates/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/tax-rate/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/tax-reliefs/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/how-to-declare-income/type-of-assessment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/balance-of-tax-payment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/mode-of-payment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/penalty-on-late-payment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/tax-estimation-advance-payment/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/payment/tax-refund/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/registration/automatic/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/registration/manual/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/registration/online-e-daftar/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/residence-status/certificate-of-residence/
# Scraping: https://www.hasil.gov.my/en/individual/individual-life-cycle/residence-status/section-7/
# Scraping: https://www.hasil.gov.my/en/individual/others/amended-assessment/arf/
# Scraping: https://www.hasil.gov.my/en/individual/others/amended-assessment/e-filing-e-application-for-amended-be/
# Scraping: https://www.hasil.gov.my/en/individual/others/amended-assessment/manual/
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-other-forms/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/application-info/application-form/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/application-info/clarification-of-activities-which-are-eligible/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/application-info/general-explanation-regarding-the-contents-of-the-constitution/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/application-info/penjelasan-berkaitan-penolakan-permohonan-eng/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/application-info/persediaan-untuk-memohon-kelulusan-kphdn-eng/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/frequently-asked-questions/berkaitan-perkara-umum-subseksyen-44-6/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/frequently-asked-questions/berkaitan-rumah-ibadat-subsekyen-44-6-pu-a-1392020-pua-522017/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/frequently-asked-questions/berkaitan-wakaf-dan-endowment-44-11d/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/public-info/brief-explanation-relating-to-concessions-approved-by-the-dgir/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/public-info/overview-in-relation-to-the-approval-of-the-dgir-under-subsection-44-6/
# Scraping: https://www.hasil.gov.my/en/institutionsorganizationsfunds-primarily-is-not-for-profit/public-info/responsibilities-and-role-of-the-cdgir/
# Scraping: https://www.hasil.gov.my/en/international/hidef-prod-portal/
# Scraping: https://www.hasil.gov.my/en/international/hidef-test-portal/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/common-reporting-standard-crs/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/country-by-country-reporting-cbcr/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/foreign-account-tax-compliance-act-fatca/
# Scraping: https://www.hasil.gov.my/en/international/double-taxation-agreement/
# ❌ Error scraping https://www.hasil.gov.my/en/international/double-taxation-agreement/: 500 Server Error: Internal Server Error for url: https://www.hasil.gov.my/en/international/double-taxation-agreement/
# Scraping: https://www.hasil.gov.my/en/international/double-taxation-avoidance-agreement-dta/contact-us/
# Scraping: https://www.hasil.gov.my/en/international/double-taxation-avoidance-agreement-dta/double-tax-agreements-withholding-tax-rates/
# Scraping: https://www.hasil.gov.my/en/international/double-taxation-avoidance-agreement-dta/effective-dtas/
# Scraping: https://www.hasil.gov.my/en/international/double-taxation-avoidance-agreement-dta/effective-tiea/
# Scraping: https://www.hasil.gov.my/en/international/double-taxation-avoidance-agreement-dta/gazetted-dtas/
# Scraping: https://www.hasil.gov.my/en/international/double-taxation-avoidance-agreement-dta/limited-agreement/
# Scraping: https://www.hasil.gov.my/en/international/double-taxation-avoidance-agreement-dta/taipei-economic-and-cultural-office-teco/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/flowchart-the-application-of-gmt/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/frequently-asked-questions-faq-on-gmt/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/gmt-guidelines/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/how-to-calculate-the-top-up-tax/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/implementation-timeline-of-gmt-in-malaysia/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/to-whom-the-gmt-apply-to/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/what-is-an-mne-group/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/what-is-malaysia-s-position-on-gmt/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/what-is-qdmtt/
# Scraping: https://www.hasil.gov.my/en/international/global-minimum-tax-gmt/what-is-top-up-tax/
# Scraping: https://www.hasil.gov.my/en/international/incentives/double-deduction-for-promotion-of-exports/
# Scraping: https://www.hasil.gov.my/en/international/incentives/industrial-adjustment-allowance-iaa/
# Scraping: https://www.hasil.gov.my/en/international/incentives/infrastructure-allowance/
# Scraping: https://www.hasil.gov.my/en/international/incentives/investment-tax-allowance/
# Scraping: https://www.hasil.gov.my/en/international/incentives/pioneer-status/
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-individual/
# Scraping: http://www.hasil.gov.my/en/media-release/?page=1
# ❌ Error scraping http://www.hasil.gov.my/en/media-release/?page=1: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/media-release/?page=2
# ❌ Error scraping http://www.hasil.gov.my/en/media-release/?page=2: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/media-release/?page=3
# ❌ Error scraping http://www.hasil.gov.my/en/media-release/?page=3: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/media-release/?page=4
# ❌ Error scraping http://www.hasil.gov.my/en/media-release/?page=4: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/media-release/?page=5
# ❌ Error scraping http://www.hasil.gov.my/en/media-release/?page=5: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/media-release/?page=6
# ❌ Error scraping http://www.hasil.gov.my/en/media-release/?page=6: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/media-release/?page=8
# ❌ Error scraping http://www.hasil.gov.my/en/media-release/?page=8: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=165fe1ab-534c-4a42-87c7-4156fd433f33
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=286949d4-b666-4ac1-82f2-7c988f4f87b4
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=313aed27-9f2b-4bf5-b448-39b44d2a0b35
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=3d27700b-57e6-4239-b7f2-1183ac06faf6
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=47c9edfe-4a4a-413c-97a6-c5100d042f45
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=53cc4f83-86ec-4e44-96d8-7345dcb2d335
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=55091f83-3baa-44a1-bf89-cb55d2f42277
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=57888d7c-808f-41a2-92e4-ce25ccfe8370
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=5ef83f0a-2c1f-473b-b92d-e2183fe3a244
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=5fb9f1c3-ad3a-4df1-bf90-d5c28bd3b531
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=679d7a10-6d70-43a1-873d-bdc4924de0e4
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=74bc978f-a21f-462a-81c0-b79dbd55883c
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=84d754d3-a28d-4be9-9893-80adaba75dc6
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=8be06f9b-3761-4f10-bd2b-b99cc411600f
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=929ac431-4154-4a96-baab-7cc8826b6036
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=a3821bd9-efbf-4ab2-87d4-2dcde8da94c9
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=a3dd21a5-3082-44c1-8a70-95c33e6a3bcf
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=a74f071b-da34-461d-af0b-52f05cce46b2
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=ca5d33d5-ef61-4685-a6db-733af8121a1b
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=d1029f1e-3344-4c0c-8901-729c09720d13
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=d499dddb-7b50-42f2-b268-0a0219541045
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=d7d66a1f-93ed-44ca-9f77-6b4a9c4c8a11
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=e4d3c52a-a35f-41d4-a4c6-9700e244dd8f
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=f06855a8-2dc8-48fe-93dc-853d680aed1d
# Scraping: https://www.hasil.gov.my/en/media-release-detail/?UniqueId=f58ec555-1763-41f4-ad1e-f52063f90660
# Scraping: https://www.hasil.gov.my/en/quick-links/procurement/eprocurement/
# Scraping: https://www.hasil.gov.my/en/quick-links/procurement/supplier-portal/
# Scraping: https://www.hasil.gov.my/en/quick-links/procurement/tender-quotation-list/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/e-cp39/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/e-dts-c/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/implementation-of-tax-identification-number-tin/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/information-collection-program/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/irbm-taxpayer-roadmap/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/mitrs/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/open-statistics/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/statistic/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/donation-approval/garis-panduan-di-bawah-perintah-cukai-pendapatan-pengecualian-2020-pu-a-1392020/
# ❌ Error scraping https://www.hasil.gov.my/en/quick-links/services/donation-approval/garis-panduan-di-bawah-perintah-cukai-pendapatan-pengecualian-2020-pu-a-1392020/: HTTPSConnectionPool(host='www.hasil.gov.my', port=443): Read timed out. (read timeout=15)
# Scraping: https://www.hasil.gov.my/en/quick-links/services/donation-approval/guidelines-under-subsection-44-11d-of-the-income-tax-act-1967/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/donation-approval/guidelines-under-subsection-44-6-of-the-income-tax-act-1967/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/donation-approval/others-1/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/donation-approval/pu-a-1392020/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/donation-approval/subsection-44-11d-of-the-income-tax-act-1967/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/donation-approval/subsection-44-6-of-the-income-tax-act-1967/
# Scraping: https://www.hasil.gov.my/en/announcement/
# Scraping: https://www.hasil.gov.my/en/contact-us/submit-to-us/hasil-helpdesk/?cat=Permohonan
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/hasil-service-counter-operation-hours/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/utc-and-operating-hours/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/client-charter/client-charter-achievement/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/irbm-corporate-plan/tekad-hasil-2026-2030-e-book/
# Scraping: https://www.hasil.gov.my/en/about-hasil/corporate-profile/irbm-corporate-plan/tekad-hasil-2026-2030-leaflet/
# Scraping: https://www.hasil.gov.my/en/forms/download-forms/download-form-other-forms/?subKategoriLainLain=Sila%20Pilih&tahun=0000
# Scraping: https://www.hasil.gov.my/en/about-hasil/hasil-directory/?bt_kump=2&bt_skum=2&bt_posi=1&bt_unit=4&bt_sequ=1
# Scraping: https://www.hasil.gov.my/en/contact-us/?bt_kump=2&bt_skum=1&bt_posi=1&bt_unit=2&bt_sequ=1
# Scraping: https://www.hasil.gov.my/en/contact-us/customer-care-officer/academy/
# Scraping: https://www.hasil.gov.my/en/contact-us/customer-care-officer/sector-department/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/
# Scraping: https://www.hasil.gov.my/en/e-invoice/communication-and-publicity/e-invoice-awareness-education-video/
# Scraping: https://www.hasil.gov.my/en/e-invoice/communication-and-publicity/infographic/
# Scraping: https://www.hasil.gov.my/en/e-invoice/communication-and-publicity/interview/
# Scraping: https://www.hasil.gov.my/en/e-invoice/communication-and-publicity/media-release/
# Scraping: https://www.hasil.gov.my/en/e-invoice/communication-and-publicity/news-article-publication/
# Scraping: https://www.hasil.gov.my/en/e-invoice/contact-us/submit-to-us/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/seminar-e-invois-hasil-bersama-pks-edisi-johor/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/seminar-e-invois-hasil-selangor-bersama-pks-shah-alam/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/taklimat-e-invois-bersama-pmks-bintulu/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/taklimat-e-invois-bersama-pmks-kuching/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/taklimat-e-invois-bukit-mertajam/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/taklimat-e-invois-teluk-intan/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/taklimat-pelaksanaan-e-invois-bersama-pmks-miri/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/taklimat-pelaksanaan-e-invois-johor-bahru/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/taklimat-pelaksanaan-e-invois-kluang/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/taklimat-pelaksanaan-e-invois-muar/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/taklimat-pelaksanaan-e-invois-pagi/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/dec2024/taklimat-pelaksanaan-e-invois-petang/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/nov2024/nasihat-sokongan-peniaga-edisi-e-invois/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/nov2024/nasihat-sokongan-peniaga-taklimat-e-invois/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/nov2024/seminar-e-invois-hasil-bersama-pks-apm/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/nov2024/seminar-e-invois-hasil-bersama-pmks-miri/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/nov2024/taklimat-e-invois-hasil-terengganu/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/nov2024/taklimat-e-invois-keningau/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/oct2024/seminar-e-invois-hasil-bersama-pks-pahang-edition/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/oct2024/seminar-e-invois-hasil-bersama-pks/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/oct2024/taklimat-e-invois/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/oct2024/taklimat-pelaksanaan-e-invois-fasa-2-3/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2024/oct2024/taklimat-pengenalan-kepada-e-invois/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/apr2025/taklimat-e-invois-bersama-pmks-kuching-siri-62025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/apr2025/taklimat-e-invois-bersama-pmks-kuching-siri-72025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/apr2025/taklimat-e-invois-hasil-negeri-sembilan/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/apr2025/taklimat-e-invois-peringkat-negeri-melaka-siri-2/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/feb2025/seminar-e-invois-hasil-bersama-pks-edisi-kedah-perlis/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/feb2025/seminar-e-invois-hasil-bersama-pks-edisi-kelantan/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/feb2025/taklimat-e-invois-bersama-pmks-siri-12025-kuching/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/feb2025/taklimat-e-invois-lhdnm-melaka/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/jan2025/taklimat-e-invois-peringkat-negeri-perak-taiping/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/jan2025/webinar-e-invois-peringkat-negeri-perak/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/jan2025/webinar-e-invois/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/best-edisi-peniaga-taklimat-peniaga-bijak-taklimat-e-invois/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/kome-buntu-teman-bantu-edisi-pengenalan-dan-pelaksanaan-e-invois-bil-12025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/kome-buntu-teman-bantu-edisi-pengenalan-dan-pelaksanaan-e-invois-bil-22025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-e-invois-bersama-pmks-bintulu-bil-12025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-e-invois-bersama-pmks-bintulu-bil-22025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-e-invois-bersama-pmks-kuching-siri-22025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-e-invois-bersama-pmks-kuching-siri-32025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-e-invois-bersama-pmks-kuching-siri-42025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-e-invois-bersama-pmks-kuching-siri-52025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-e-invois-hasil-bersama-pmks-miri-bil12025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-e-invois-hasil-bersama-pmks-miri-bil22025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-e-invois-hasil-bersama-pmks-sibu-bil-12025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-e-invois-hasil-bersama-pmks-sibu-bil-22025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/taklimat-pelaksanaan-e-invois-bersama-pmks/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/webinar-e-invois-hasil-bersama-pmks-miri-bil-32025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/webinar-e-invois-hasil-bersama-pmks-miri-bil-42025/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/webinar-e-invois-kedah-siri-2/
# Scraping: https://www.hasil.gov.my/en/e-invoice/e-invoice-events/2025/mar2025/webinar-pengenalan-e-invois-untuk-pks-kelantan/
# Scraping: https://www.hasil.gov.my/en/e-invoice/implementation-of-e-invoicing-in-malaysia/about-e-invoice/
# Scraping: https://www.hasil.gov.my/en/e-invoice/implementation-of-e-invoicing-in-malaysia/benefits-of-e-invoice/
# Scraping: https://www.hasil.gov.my/en/e-invoice/implementation-of-e-invoicing-in-malaysia/e-invoice-implementation-timeline/
# Scraping: https://www.hasil.gov.my/en/e-invoice/implementation-of-e-invoicing-in-malaysia/overview-of-the-e-invoice-model/
# Scraping: https://www.hasil.gov.my/en/e-invoice/myinvois-portal/about-myinvois-portal/
# Scraping: https://www.hasil.gov.my/en/e-invoice/myinvois-portal/user-guide-video/
# Scraping: https://www.hasil.gov.my/en/e-invoice/reference-for-the-implementation-of-e-invoice/frequently-asked-questions/industry-specific-frequently-asked-questions/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/hasil/2025/jan2025/program-business-and-entreprenuer-support-training-best-edisi-perniagaan/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/hasil/2025/jan2025/seminar-belanjawan-2025-bersemuka/
# ...
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/negeri-sembilan/2025/apr2025/webinar-hasil-negeri-sembilan-rahsia-jimat-cukai-e-filing-e-be-2024-20250415/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/negeri-sembilan/2025/apr2025/webinar-hasil-negeri-sembilan-rahsia-jimat-cukai-e-filing-e-be-2024-20250418/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/negeri-sembilan/2025/apr2025/webinar-hasil-negeri-sembilan-rahsia-jimat-cukai-e-filing-e-be-2024/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/perak/2025/mar2025/webinar-kome-buntu-teman-bantu-e-filing-rahsia-jimat-cukai-20250319/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/perak/2025/mar2025/webinar-kome-buntu-teman-bantu-e-filing-rahsia-jimat-cukai-20250320/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/perak/2025/mar2025/webinar-kome-buntu-teman-bantu-e-filing-rahsia-jimat-cukai-20250324/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/perak/2025/mar2025/webinar-kome-buntu-teman-bantu-e-filing-rahsia-jimat-cukai-20250325/
# ❌ Error scraping https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/perak/2025/mar2025/webinar-kome-buntu-teman-bantu-e-filing-rahsia-jimat-cukai-20250325/: HTTPSConnectionPool(host='www.hasil.gov.my', port=443): Read timed out. (read timeout=15)
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/perak/2025/mar2025/webinar-kome-buntu-teman-bantu-e-filing-rahsia-jimat-cukai-20250326/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/perak/2025/mar2025/webinar-kome-buntu-teman-bantu-e-pcb-plus-20250306/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/perak/2025/mar2025/webinar-kome-buntu-teman-bantu-e-pcb-plus-20250310/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/perak/2025/mar2025/webinar-kome-buntu-teman-bantu-e-pcb-plus-20250313/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/pulau-pinang/2025/jan2025/program-business-entrepreneur-support-and-training-best-21-jan-2025/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/pulau-pinang/2025/jan2025/program-business-entrepreneur-support-and-training-best/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/sabah/2025/jan2025/taklimat-percukaian-e-invois-best-bil-12025/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/sabah/2025/jan2025/taklimat-percukaian-e-invois-labuan/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/sabah/2025/jan2025/taklimat-percukaian-e-invois-tawau/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/selangor/2025/feb2025/program-nasihat-sokongan-peniaga-business-entrepreneur-support-and-training-best/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/selangor/2025/mar2025/taklimat-e-invois-best/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/terengganu/2025/feb2025/program-business-entrepreneur-support-and-training-best-edisi-perniagaanusahawan-25feb2025/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/terengganu/2025/feb2025/program-business-entrepreneur-support-and-training-best-edisi-perniagaanusahawan/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/terengganu/2025/feb2025/taklimat-percukaian-klik-hasil/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/terengganu/2025/jan2025/taklimat-percukaian-klik-hasil-09jan2025/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/terengganu/2025/jan2025/taklimat-percukaian-klik-hasil-14jan2025/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/terengganu/2025/mar2025/program-business-entrepreneur-support-and-training-best-edisi-majikan-12mar2025/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/terengganu/2025/mar2025/program-business-entrepreneur-support-and-training-best-edisi-majikan/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/terengganu/2025/mar2025/program-business-entrepreneur-support-and-training-best-edisi-perniagaanusahawan/
# Scraping: https://www.hasil.gov.my/en/eduzone/program-pendidikan-dan-kesedaran-cukai/tax-education-program/terengganu/2025/mar2025/program-business-entreprenuer-support-and-training-best-edisi-perniagaanusahawan/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/cooperative-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/corporate-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/digital-economy/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/employer-and-employee/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/gig-economy/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/hasil-e-book-at-a-glance/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/individual/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/information/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/real-property-gains-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/shadow-economy/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/stamp-duty/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2022/withholding-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/cooperative-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/corporate-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/digital-economy/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/employer-and-employee/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/gig-economy/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/individual/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/information/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/real-property-gains-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/shadow-economy/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/stamp-duty/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/tax-brochure-2023/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2023/withholding-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/cooperative-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/corporate-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/digital-economy/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/e-invoice/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/employer-and-employee/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/gig-economy/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/hasil-e-book-at-a-glance/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/individual/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/information/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/real-property-gains-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/report-tax-refugee-activities/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/shadow-economy/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/stamp-duty/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2024/withholding-tax/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-brochure/tax-brochure-2025/tax-advisory-brochure/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-12020/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-12021/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-12022/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-12023/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-12024/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-22020/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-22021/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-22022/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-22023/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-22024/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-32020/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-32022/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/berita-hasil/berita-hasil-bil-32023/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/e-newsletter-hasil/e-newsletter-hasil-2021/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/e-newsletter-hasil/e-newsletter-hasil-2022/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/e-newsletter-hasil/e-newsletter-hasil-2023/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/e-newsletter-hasil/e-newsletter-hasil-2024/
# Scraping: https://www.hasil.gov.my/en/eduzone/tax-publication/e-newsletter-hasil/e-newsletter-hasil-2025/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/common-reporting-standard-crs/crs-faq/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/common-reporting-standard-crs/crs-faq/?bt_kump=6&bt_skum=2&bt_posi=1&bt_unit=2&bt_sequ=8
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/common-reporting-standard-crs/crs-submission/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/common-reporting-standard-crs/crs-submission/?bt_kump=10&bt_skum=1&bt_posi=1&bt_unit=1&bt_sequ=256
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/common-reporting-standard-crs/crs-xml-schema-user-guide/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/common-reporting-standard-crs/crs-xml-schema-user-guide/crs-xml-file-sample-version-2/?bt_kump=6&bt_skum=2&bt_posi=1&bt_unit=2&bt_sequ=5
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/common-reporting-standard-crs/information-on-registration-of-malaysian-financial-institution-myfi/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/common-reporting-standard-crs/information-on-registration-of-malaysian-financial-institution-myfi/?bt_kump=6&bt_skum=2&bt_posi=1&bt_unit=2&bt_sequ=3
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/country-by-country-reporting-cbcr/country-by-country-reporting/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/foreign-account-tax-compliance-act-fatca/fatca-news/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/foreign-account-tax-compliance-act-fatca/guidance-notes/
# Scraping: https://www.hasil.gov.my/en/quick-links/procurement/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/e-cp39/frequently-asked-question-e-cp39/
# Scraping: https://www.hasil.gov.my/en/quick-links/services/donation-approval/?negeri=&Organisasi=
# Scraping: http://www.hasil.gov.my/en/announcement/?page=1
# ❌ Error scraping http://www.hasil.gov.my/en/announcement/?page=1: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/announcement/?page=2
# ❌ Error scraping http://www.hasil.gov.my/en/announcement/?page=2: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/announcement/?page=3
# ❌ Error scraping http://www.hasil.gov.my/en/announcement/?page=3: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: http://www.hasil.gov.my/en/announcement/?page=4
# ❌ Error scraping http://www.hasil.gov.my/en/announcement/?page=4: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/headquarters-of-inland-revenue-board-of-malaysia/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/johor/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/kedah/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/kelantan/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/klang-valley/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/melaka/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/negeri-sembilan/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/pahang/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/perak/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/perlis/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/pulau-pinang/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/sabah/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/sarawak/
# Scraping: https://www.hasil.gov.my/en/contact-us/walk-in-to-our-office/location/terengganu/
# Scraping: https://www.hasil.gov.my/en/e-invoice/communication-and-publicity/infographic/coretan-e-invois/
# Scraping: https://www.hasil.gov.my/en/e-invoice/communication-and-publicity/infographic/e-invoice-faq/
# Scraping: https://www.hasil.gov.my/en/e-invoice/communication-and-publicity/infographic/e-invois-hasil-info/
# Scraping: https://www.hasil.gov.my/en/e-invoice/contact-us/submit-to-us/e-invois-hasil-email/
# Scraping: https://www.hasil.gov.my/en/international/automatic-exchange-of-information-aeoi/common-reporting-standard-crs/crs-xml-schema-user-guide/crs-xml-file-sample-version-2/
# ✅ Total links visited: 605
